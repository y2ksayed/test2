# %%
##Homework due 12/18/19. Colleen McGroarty 
##Lab Cleaning Rock Song Data 

import pandas as pd
import numpy as np 
import seaborn as sns

# %matplotlib inline

# %%
rockfile = pd.read_csv('/Users/rahmanss/Downloads/DAT-course-materials-students-master 4/lessons/working-with-data/rock.csv', sep=',')

# %%
rockfile.head()
# Out:
#                Song Clean ARTIST CLEAN Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %%
# 2.A replace column headers 
rock_cols=('Song_title', 'Artist', 'Release_year', 'title_Artist', 'First?', 'Year?', 'playcount', 'F*G')
rockfile = pd.read_csv('/Users/rahmanss/Downloads/DAT-course-materials-students-master 4/lessons/working-with-data/rock.csv', skiprows=1, names=rock_cols)
rockfile
# Out:
#                                        Song_title         Artist Release_year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 10                          Baby, Please Don't Go          AC/DC          NaN
# ...

# %%
#2B Replace column headers 
rockfile.rename(columns={'Song_title':'SONGS_title_new', 'Artist':'ARTIST', 'Release_year':'YEAR'}, inplace=True)

# %%
##2C Rename columns 
rockfile.columns
# Out:
# Index(['SONGS_title_new', 'ARTIST', 'YEAR', 'title_Artist', 'First?', 'Year?',
#        'playcount', 'F*G'],
#       dtype='object')

# %%
# 3 Show records where df['release'] is null 

rockfile.info()

rockfile.YEAR.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# SONGS_title_new    2230 non-null object
# ARTIST             2230 non-null object
# YEAR               1653 non-null object
# title_Artist       2230 non-null object
# First?             2230 non-null int64
# Year?              2230 non-null int64
# playcount          2230 non-null int64
# F*G                2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10       True
# 11      False
# 12      False
# 13       True
# 14      False
# 15      False
# 16       True
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24       True
# 25       True
# 26       True
# 27      False
# 28      False
# 29       True
#         ...
# ...

# %%
#4a # Replace release nulls with 0

#rockfile.loc[:, 'Release_year'] = 0

# %%
#4b 
rocknull=rockfile.YEAR.isnull()
rockfile.loc[rocknull, 'YEAR'] = 0

# %%
rockfile
# Out:
#                                   SONGS_title_new         ARTIST  YEAR  \
# 0                                Caught Up in You    .38 Special  1982
# 1                                    Fantasy Girl    .38 Special     0
# 2                                 Hold On Loosely    .38 Special  1981
# 3                          Rockin' Into the Night    .38 Special  1980
# 4                               Art For Arts Sake           10cc  1975
# 5                                      Kryptonite   3 Doors Down  2000
# 6                                           Loser   3 Doors Down  2000
# 7                                   When I'm Gone   3 Doors Down  2002
# 8                                      What's Up?  4 Non Blondes  1992
# 9                                      Take On Me           a-ha  1985
# 10                          Baby, Please Don't Go          AC/DC     0
# 11                                  Back In Black          AC/DC  1980
# ...

# %%
#5a 
rockfile.dtypes
#yes columns and data types don't match
# Out:
# SONGS_title_new    object
# ARTIST             object
# YEAR               object
# title_Artist       object
# First?              int64
# Year?               int64
# playcount           int64
# F*G                 int64
# dtype: object

# %%
#6a

# %%
#6c

# %%
#6c

# %%
#7a Print out the summary stats for the release column. What is the earliest and latest release date?
rockfile.describe()
# Out:
#        First?        Year?    playcount          F*G
# count  2230.0  2230.000000  2230.000000  2230.000000
# mean      1.0     0.741256    16.872646    15.048430
# std       0.0     0.438043    25.302972    25.288366
# min       1.0     0.000000     0.000000     0.000000
# 25%       1.0     0.000000     1.000000     0.000000
# 50%       1.0     1.000000     4.000000     3.000000
# 75%       1.0     1.000000    21.000000    18.000000
# max       1.0     1.000000   142.000000   142.000000

# %%
#7B it's taking the 0's into account when averaging the mean of the release year 
rockfile["playcount"].mean()
# Out:
# 16.872645739910315

# %%
#8a
#8

# %%
#9
