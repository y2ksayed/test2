# %%
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
import pandas as pd
os.chdir('C:\\Users\\ro44\Documents\\GitHub\\DAT-course-materials-students\\lessons\\working-with-data')
housing=pd.read_csv('.\\boston_housing_data.csv')

housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
housing.columns=["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE",
         "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     1.716290   11.363636   11.136779    0.069170    0.554695    6.284634
# std      2.653510   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.250895    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      2.326718   12.500000   18.100000    0.000000    0.624000    6.623500
# max      9.966540  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.696228    4.332016  408.237154   18.455534  356.674032
# ...

# %%
housing.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#doenst make sense to count Median for Zone

# %%
sns.pairplot(housing)

# %%
sns.heatmap(housing.corr())

# %%
housing.plot(x='TAX', y='CRIM', kind='scatter', color='dodgerblue', figsize=(15,7), s=20);

# %%
housing.corr().unstack().sort_values().drop_duplicates()
#lists highest correlations
# Out:
# NOX    DIS     -0.748872
# LSTAT  MEDV    -0.737663
# AGE    DIS     -0.713313
# INDUS  DIS     -0.678498
# LSTAT  RM      -0.613808
#                   ...
# INDUS  TAX      0.720760
# NOX    AGE      0.731470
#        INDUS    0.763651
# TAX    CRIM     0.793392
# CRIM   CRIM     1.000000
# Length: 92, dtype: float64

# %%
housing.hist(figsize=(20,20), bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020E7FF41BC8>,
# ...
#       dtype=object)

# %%
#6 RM has normal distribution
 # DIS has left skwing distribution
 # AGE has the most right skwing distribution

# %%
# 7  Conduct a full univariate analysis on MEDV, CHAS, TAX, and RAD.

print(housing[['MEDV','TAX','CHAS','RAD']].mean())
print(housing[['MEDV','TAX','CHAS','RAD']].mode())
print(housing[['MEDV','TAX','CHAS','RAD']].median())
#ths uses descriptive statistics
# Out:
# MEDV     22.532806
# TAX     408.237154
# CHAS      0.069170
# RAD       4.332016
# dtype: float64
#    MEDV    TAX  CHAS  RAD
# 0  50.0  666.0     0    4
# MEDV     21.2
# TAX     330.0
# CHAS      0.0
# RAD       4.0
# dtype: float64

# %%
import random
age=list(housing['AGE'])
random.sample(age,15)
# Out:
# [51.9,
#  45.8,
#  79.9,
#  68.8,
#  100.0,
#  100.0,
#  100.0,
#  56.7,
#  90.7,
#  37.8,
#  83.3,
#  52.6,
#  99.1,
#  97.1,
#  84.7]

# %%
import numpy as np
import scipy.stats as stats
import csv
import seaborn as sns

# %matplotlib inline

# %%
import os
import pandas as pd
os.chdir('C:\\Users\\ro44\Documents\\GitHub\\DAT-course-materials-students\\lessons\\working-with-data')

# %%
sales=pd.read_csv('.\\sales_info.csv')
sales.head()
# Out:
#    volume_sold  2015_margin  2015_q1_sales  2016_q1_sales
# 0    18.420760    93.802281      337166.53      337804.05
# 1     4.776510    21.082425       22351.86       21736.63
# 2    16.602401    93.612494      277764.46      306942.27
# 3     4.296111    16.824704       16805.11        9307.75
# 4     8.156023    35.011457       54411.42       58939.90

# %%
sales.columns
# Out:
# Index(['volume_sold', '2015_margin', '2015_q1_sales', '2016_q1_sales'], dtype='object')

# %%
sales_data_values = []
sales_data_values.append(list(sales['volume_sold']))
sales_data_values.append(list(sales['2015_margin']))
sales_data_values.append(list(sales['2015_q1_sales']))
sales_data_values.append(list(sales['2016_q1_sales']))

# %%
sales_data_values[2]
# Out:
# [337166.53,
#  22351.86,
#  277764.46,
#  16805.11,
#  54411.42,
#  255939.81,
#  319020.69,
#  45340.33,
#  57849.23,
#  51031.04,
#  68657.91,
#  4151.93,
#  121837.56,
#  146725.31,
#  119287.76,
#  20335.03,
#  110552.94,
#  204237.78,
#  16939.15,
#  55498.12,
#  15983.98,
#  71758.66,
#  62988.17,
#  29637.75,
#  48759.71,
#  89736.7,
#  5577.61,
#  310035.66,
#  310718.21,
#  258284.84,
#  150049.71,
#  309568.16,
#  66468.32,
#  321983.24,
#  115531.13,
#  926706.76,
#  157981.2,
#  51078.36,
#  272703.74,
#  180760.93,
#  72185.66,
#  263161.4,
#  164809.62,
#  60986.22,
#  210690.45,
#  139068.33,
#  209403.19,
#  75110.03,
#  123291.57,
#  157591.18,
#  163684.93,
#  146850.63,
#  143950.01,
#  136167.32,
#  327172.32,
#  105869.94,
#  176266.68,
#  176720.07,
#  44836.7,
#  65830.25,
#  228680.53,
#  73810.68,
#  54655.98,
#  156056.28,
#  80923.05,
#  167606.75,
#  25575.88,
#  211902.95,
#  312502.67,
#  85217.68,
#  89525.66,
#  176252.03,
#  68258.49,
#  88008.31,
# ...

# %%
sales_df=pd.DataFrame(sales_data_values)

# %%
sales_df.loc[0].head()
# Out:
# 0    18.420760
# 1     4.776510
# 2    16.602401
# 3     4.296111
# 4     8.156023
# Name: 0, dtype: float64
