# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

rockfile = pd.read_csv('/Users/rahmanss/Downloads/DAT-course-materials-students-master 3/lessons/working-with-data/rock.csv', sep=',')
rockfile.head(2)
# Out:
#          Song Clean ARTIST CLEAN Release Year  \
# 0  Caught Up in You  .38 Special         1982
# 1      Fantasy Girl  .38 Special          NaN
#
#                           COMBINED  First?  Year?  PlayCount  F*G
# 0  Caught Up in You by .38 Special       1      1         82   82
# 1      Fantasy Girl by .38 Special       1      0          3    0

# %%
print(rockfile.columns)
# Out:
# Index(['Song Clean', 'ARTIST CLEAN', 'Release Year', 'COMBINED', 'First?',
#        'Year?', 'PlayCount', 'F*G'],
#       dtype='object')

# %%
rockfile.rename(columns={'Song Clean':'song', 'ARTIST CLEAN':'artist','Release Year':'release','COMBINED':'combined'}, inplace=True)

# %%
rockfile[rockfile.release.isnull()].head()
# Out:
#                       song       artist release  \
# 1             Fantasy Girl  .38 Special     NaN
# 10   Baby, Please Don't Go        AC/DC     NaN
# 13  CAN'T STOP ROCK'N'ROLL        AC/DC     NaN
# 16        Girls Got Rhythm        AC/DC     NaN
# 24         Let's Get It Up        AC/DC     NaN
#
#                            combined  First?  Year?  PlayCount  F*G
# 1       Fantasy Girl by .38 Special       1      0          3    0
# 10   Baby, Please Don't Go by AC/DC       1      0          1    0
# 13  CAN'T STOP ROCK'N'ROLL by AC/DC       1      0          5    0
# 16        Girls Got Rhythm by AC/DC       1      0         24    0
# 24         Let's Get It Up by AC/DC       1      0          4    0

# %%
rockfile['release'].fillna(0,inplace=True)

# %%
rockfile.release.isnull().sum()
# Out:
# 0

# %%
rockfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# song         2230 non-null object
# artist       2230 non-null object
# release      2230 non-null object
# combined     2230 non-null object
# First?       2230 non-null int64
# Year?        2230 non-null int64
# PlayCount    2230 non-null int64
# F*G          2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB

# %%
rockfile.release.value_counts()
# Out:
# 0                577
# 1973             104
# 1977              83
# 1975              83
# 1970              81
# 1971              75
# 1969              72
# 1980              70
# 1978              64
# 1979              63
# 1967              61
# 1981              61
# 1983              60
# 1976              56
# 1982              54
# 1984              51
# 1972              50
# 1974              48
# 1968              46
# 1985              39
# 1987              39
# 1986              37
# 1991              34
# 1989              32
# 1966              30
# 1988              29
# 1965              28
# 1994              25
# 1990              22
# 1993              19
# 1992              14
# 1964              14
# 1999              13
# 1995              10
# 1996               9
# 1963               9
# 1997               9
# 1998               6
# 2002               6
# 2004               5
# 2005               5
# 2012               5
# 2001               4
# ...

# %%
rockfile[rockfile['release'] == 'SONGFACTS.COM'].head()
# Out:
#                 song          artist        release  \
# 1504  Bullfrog Blues  Rory Gallagher  SONGFACTS.COM
#
#                               combined  First?  Year?  PlayCount  F*G
# 1504  Bullfrog Blues by Rory Gallagher       1      1          1    1

# %%
rockfile.release.loc[1504].replace = 0
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
rockfile.release.value_counts()
# Out:
# 0       578
# 1973    104
# 1977     83
# 1975     83
# 1970     81
# 1971     75
# 1969     72
# 1980     70
# 1978     64
# 1979     63
# 1967     61
# 1981     61
# 1983     60
# 1976     56
# 1982     54
# 1984     51
# 1972     50
# 1974     48
# 1968     46
# 1985     39
# 1987     39
# 1986     37
# 1991     34
# 1989     32
# 1966     30
# 1988     29
# 1965     28
# 1994     25
# 1990     22
# 1993     19
# 1992     14
# 1964     14
# 1999     13
# 1995     10
# 1996      9
# 1963      9
# 1997      9
# 1998      6
# 2002      6
# 2004      5
# 2005      5
# 2012      5
# 2001      4
# 1962      3
# 2000      3
# 2011      3
# 2003      3
# 2007      3
# 2008      3
# 2014      2
# 2013      2
# 1958      1
# 1955      1
# 1961      1
# 1071      1
# 2006      1
# Name: release, dtype: int64

# %%
rockfile.release.describe()
# Out:
# count     2230
# unique      56
# top          0
# freq       578
# Name: release, dtype: int64

# %%
rockfile.loc[0,'song':'release']
# Out:
# song       Caught Up in You
# artist          .38 Special
# release                1982
# Name: 0, dtype: object

# %%
def myfunction(n):
    if int(rockfile.loc[n,'release']) < 1970:
        print('Before 1970')
    else: 
        print('After 1970')
    return(rockfile.loc[n,'song':'release'])
>>> print(", ".join(["ha" if i else "Ha" for i in range(3)]) + "!")
Ha, ha, ha!

[unicode(x.strip()) if x is not None else '' for x in row]

# %%
['Before 1970' if x < 1970 else 'After 1970' for x in rockfile["Release Year"].notnull()]
# Out:
# ['Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
#  'Before 1970',
# ...

# %%
rockfile["Release Year"]
# Out:
# 0       1982
# 1        NaN
# 2       1981
# 3       1980
# 4       1975
# 5       2000
# 6       2000
# 7       2002
# 8       1992
# 9       1985
# 10       NaN
# 11      1980
# 12      1993
# 13       NaN
# 14      1976
# 15      1981
# 16       NaN
# 17      1995
# 18      1980
# 19      1980
# 20      1979
# 21      1975
# 22      1984
# 23      1977
# 24       NaN
# 25       NaN
# 26       NaN
# 27      1979
# 28      1980
# 29       NaN
#         ...
# 2200    1983
# 2201    1971
# 2202    1971
# 2203     NaN
# 2204    1971
# 2205     NaN
# 2206     NaN
# 2207    1968
# 2208     NaN
# 2209    1976
# 2210    1973
# 2211    1980
# 2212    1983
# 2213    1983
# 2214    1975
# 2215     NaN
# 2216     NaN
# 2217    1973
# 2218     NaN
# 2219    1973
# 2220    1983
# 2221     NaN
# 2222     NaN
# 2223    1981
# 2224    1983
# 2225     NaN
# 2226    1981
# 2227    1975
# 2228    1983
# 2229    1973
# Name: Release Year, Length: 2230, dtype: object
