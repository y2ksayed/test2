# %%
##Homework due 12/18/19. Colleen McGroarty 
##Lab Cleaning Rock Song Data 

import pandas as pd
import numpy as np 
import seaborn as sns

# %matplotlib inline

# %%
import os
os.chdir('/Users/colleenmcgroarty/Desktop/general_assembly')

# %%
pwd
# Out:
# '/Users/colleenmcgroarty/Desktop/general_assembly'

# %%
rockfile = pd.read_csv('./rock.csv', sep=',')

# %%
rockfile
# Out:
#                                        Song Clean ARTIST CLEAN Release Year  \
# 0                                Caught Up in You  .38 Special         1982
# 1                                    Fantasy Girl  .38 Special          NaN
# 2                                 Hold On Loosely  .38 Special         1981
# 3                          Rockin' Into the Night  .38 Special         1980
# 4                               Art For Arts Sake         10cc         1975
# ...                                           ...          ...          ...
# 2225                      She Loves My Automobile       ZZ Top          NaN
# 2226                            Tube Snake Boogie       ZZ Top         1981
# 2227                                         Tush       ZZ Top         1975
# 2228                                   TV Dinners       ZZ Top         1983
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO       ZZ Top         1973
#
#                                                COMBINED  First?  Year?  \
# 0                       Caught Up in You by .38 Special       1      1
# 1                           Fantasy Girl by .38 Special       1      0
# 2                        Hold On Loosely by .38 Special       1      1
# 3                 Rockin' Into the Night by .38 Special       1      1
# 4                             Art For Arts Sake by 10cc       1      1
# ...                                                 ...     ...    ...
# 2225                  She Loves My Automobile by ZZ Top       1      0
# 2226                        Tube Snake Boogie by ZZ Top       1      1
# 2227                                     Tush by ZZ Top       1      1
# 2228                               TV Dinners by ZZ Top       1      1
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...       1      1
#
#       PlayCount  F*G
# 0            82   82
# 1             3    0
# 2            85   85
# 3            18   18
# 4             1    1
# ...         ...  ...
# 2225          1    0
# 2226         32   32
# 2227        109  109
# 2228          1    1
# 2229          2    2
#
# [2230 rows x 8 columns]

# %%
# 2.A replace column headers 
rock_cols=('Song_title', 'Artist', 'Release_year', 'title_Artist', 'First?', 'Year?', 'playcount', 'F*G')
rockfile = pd.read_csv('./rock.csv', skiprows=1, names=rock_cols)
rockfile
# Out:
#                                        Song_title       Artist Release_year  \
# 0                                Caught Up in You  .38 Special         1982
# 1                                    Fantasy Girl  .38 Special          NaN
# 2                                 Hold On Loosely  .38 Special         1981
# 3                          Rockin' Into the Night  .38 Special         1980
# 4                               Art For Arts Sake         10cc         1975
# ...                                           ...          ...          ...
# 2225                      She Loves My Automobile       ZZ Top          NaN
# 2226                            Tube Snake Boogie       ZZ Top         1981
# 2227                                         Tush       ZZ Top         1975
# 2228                                   TV Dinners       ZZ Top         1983
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO       ZZ Top         1973
#
#                                            title_Artist  First?  Year?  \
# 0                       Caught Up in You by .38 Special       1      1
# 1                           Fantasy Girl by .38 Special       1      0
# 2                        Hold On Loosely by .38 Special       1      1
# 3                 Rockin' Into the Night by .38 Special       1      1
# 4                             Art For Arts Sake by 10cc       1      1
# ...                                                 ...     ...    ...
# 2225                  She Loves My Automobile by ZZ Top       1      0
# 2226                        Tube Snake Boogie by ZZ Top       1      1
# 2227                                     Tush by ZZ Top       1      1
# 2228                               TV Dinners by ZZ Top       1      1
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...       1      1
#
#       playcount  F*G
# 0            82   82
# 1             3    0
# 2            85   85
# 3            18   18
# 4             1    1
# ...         ...  ...
# 2225          1    0
# 2226         32   32
# 2227        109  109
# 2228          1    1
# 2229          2    2
#
# [2230 rows x 8 columns]

# %%
#2B Replace column headers 
rockfile.rename(columns={'Song_title':'SONGS', 'Artist':'ARTIST', 'Release_year':'YEAR'}, inplace=True)
rockfile
# Out:
#                                             SONGS       ARTIST  YEAR  \
# 0                                Caught Up in You  .38 Special  1982
# 1                                    Fantasy Girl  .38 Special   NaN
# 2                                 Hold On Loosely  .38 Special  1981
# 3                          Rockin' Into the Night  .38 Special  1980
# 4                               Art For Arts Sake         10cc  1975
# ...                                           ...          ...   ...
# 2225                      She Loves My Automobile       ZZ Top   NaN
# 2226                            Tube Snake Boogie       ZZ Top  1981
# 2227                                         Tush       ZZ Top  1975
# 2228                                   TV Dinners       ZZ Top  1983
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO       ZZ Top  1973
#
#                                            title_Artist  First?  Year?  \
# 0                       Caught Up in You by .38 Special       1      1
# 1                           Fantasy Girl by .38 Special       1      0
# 2                        Hold On Loosely by .38 Special       1      1
# 3                 Rockin' Into the Night by .38 Special       1      1
# 4                             Art For Arts Sake by 10cc       1      1
# ...                                                 ...     ...    ...
# 2225                  She Loves My Automobile by ZZ Top       1      0
# 2226                        Tube Snake Boogie by ZZ Top       1      1
# 2227                                     Tush by ZZ Top       1      1
# 2228                               TV Dinners by ZZ Top       1      1
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...       1      1
#
#       playcount  F*G
# 0            82   82
# 1             3    0
# 2            85   85
# 3            18   18
# 4             1    1
# ...         ...  ...
# 2225          1    0
# 2226         32   32
# 2227        109  109
# 2228          1    1
# 2229          2    2
#
# [2230 rows x 8 columns]

# %%
##2C Rename columns 
rockfile.columns = rock_cols
rockfile
# Out:
#                                        Song_title       Artist Release_year  \
# 0                                Caught Up in You  .38 Special         1982
# 1                                    Fantasy Girl  .38 Special          NaN
# 2                                 Hold On Loosely  .38 Special         1981
# 3                          Rockin' Into the Night  .38 Special         1980
# 4                               Art For Arts Sake         10cc         1975
# ...                                           ...          ...          ...
# 2225                      She Loves My Automobile       ZZ Top          NaN
# 2226                            Tube Snake Boogie       ZZ Top         1981
# 2227                                         Tush       ZZ Top         1975
# 2228                                   TV Dinners       ZZ Top         1983
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO       ZZ Top         1973
#
#                                            title_Artist  First?  Year?  \
# 0                       Caught Up in You by .38 Special       1      1
# 1                           Fantasy Girl by .38 Special       1      0
# 2                        Hold On Loosely by .38 Special       1      1
# 3                 Rockin' Into the Night by .38 Special       1      1
# 4                             Art For Arts Sake by 10cc       1      1
# ...                                                 ...     ...    ...
# 2225                  She Loves My Automobile by ZZ Top       1      0
# 2226                        Tube Snake Boogie by ZZ Top       1      1
# 2227                                     Tush by ZZ Top       1      1
# 2228                               TV Dinners by ZZ Top       1      1
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...       1      1
#
#       playcount  F*G
# 0            82   82
# 1             3    0
# 2            85   85
# 3            18   18
# 4             1    1
# ...         ...  ...
# 2225          1    0
# 2226         32   32
# 2227        109  109
# 2228          1    1
# 2229          2    2
#
# [2230 rows x 8 columns]

# %%
# 3 Show records where df['release'] is null 

rockfile.info()

rockfile.Release_year.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song_title      2230 non-null object
# Artist          2230 non-null object
# Release_year    1653 non-null object
# title_Artist    2230 non-null object
# First?          2230 non-null int64
# Year?           2230 non-null int64
# playcount       2230 non-null int64
# F*G             2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 2225     True
# 2226    False
# 2227    False
# 2228    False
# 2229    False
# Name: Release_year, Length: 2230, dtype: bool

# %%
#4a # Replace release nulls with 0

#rockfile.loc[:, 'Release_year'] = 0

# %%
#4b 
rocknull=rockfile.Release_year.isnull()
rockfile.loc[rocknull, 'Release_year'] = 0

# %%
rockfile
# Out:
#                                        Song_title       Artist Release_year  \
# 0                                Caught Up in You  .38 Special         1982
# 1                                    Fantasy Girl  .38 Special            0
# 2                                 Hold On Loosely  .38 Special         1981
# 3                          Rockin' Into the Night  .38 Special         1980
# 4                               Art For Arts Sake         10cc         1975
# ...                                           ...          ...          ...
# 2225                      She Loves My Automobile       ZZ Top            0
# 2226                            Tube Snake Boogie       ZZ Top         1981
# 2227                                         Tush       ZZ Top         1975
# 2228                                   TV Dinners       ZZ Top         1983
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO       ZZ Top         1973
#
#                                            title_Artist  First?  Year?  \
# 0                       Caught Up in You by .38 Special       1      1
# 1                           Fantasy Girl by .38 Special       1      0
# 2                        Hold On Loosely by .38 Special       1      1
# 3                 Rockin' Into the Night by .38 Special       1      1
# 4                             Art For Arts Sake by 10cc       1      1
# ...                                                 ...     ...    ...
# 2225                  She Loves My Automobile by ZZ Top       1      0
# 2226                        Tube Snake Boogie by ZZ Top       1      1
# 2227                                     Tush by ZZ Top       1      1
# 2228                               TV Dinners by ZZ Top       1      1
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...       1      1
#
#       playcount  F*G
# 0            82   82
# 1             3    0
# 2            85   85
# 3            18   18
# 4             1    1
# ...         ...  ...
# 2225          1    0
# 2226         32   32
# 2227        109  109
# 2228          1    1
# 2229          2    2
#
# [2230 rows x 8 columns]

# %%
#5a 
rockfile.dtypes
#yes columns and data types don't match
# Out:
# Song_title      object
# Artist          object
# Release_year    object
# title_Artist    object
# First?           int64
# Year?            int64
# playcount        int64
# F*G              int64
# dtype: object

# %%
#6a

# %%
#6c

# %%
#6c

# %%
#7a Print out the summary stats for the release column. What is the earliest and latest release date?
rockfile.describe()
# Out:
#        First?        Year?    playcount          F*G
# count  2230.0  2230.000000  2230.000000  2230.000000
# mean      1.0     0.741256    16.872646    15.048430
# std       0.0     0.438043    25.302972    25.288366
# min       1.0     0.000000     0.000000     0.000000
# 25%       1.0     0.000000     1.000000     0.000000
# 50%       1.0     1.000000     4.000000     3.000000
# 75%       1.0     1.000000    21.000000    18.000000
# max       1.0     1.000000   142.000000   142.000000

# %%
#7B it's taking the 0's into account when averaging the mean of the release year

# %%
#8a
#8b

# %%
#9
